# %%
import pandas as pd

# %%
# Read CSV file
df = pd.read_csv('test1.csv')

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\pandas\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Line Plot
import matplotlib.pyplot as plt

# %%
# Line Plot
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
temperature = [22,24,19,23,25]
plt.plot(days, temperature, marker = 'o', label = 'temperature')
plt.title('Temperature Over a week')
plt.xlabel('(Days)')
plt.ylabel('(Temperature ( C))')
plt.legend()
plt.show()

# %%
# Bar Chart
products = ['Mobile', 'Laptop', 'Tablet']
sales = [150,200,100]
plt.bar(products, sales, color = ['blue', 'green', 'orange'])
plt.title('Product Sales')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.show()
