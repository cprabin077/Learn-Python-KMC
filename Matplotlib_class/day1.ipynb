# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kushm.desktop-rm39q8o.000\desktop\python-learn-kmc\matplotlib_class\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Draw a line in a diagram from position (0,0) to position (6,250):

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to position (8, 10):

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting without x-points:

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# Mark each point with a circle:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# Set the size of the markers to 20:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# Set the EDGE color to red:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# Set the FACE color to red:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# Mark each point with a beautiful green color:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# Mark each point with the color named "hotpink":

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()
