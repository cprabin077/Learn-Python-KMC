# %%
# Write file -> w
f = open("hello.txt","w")
f.write("Hello World!")
f.close()

# %%
# Read File -> r
f = open("hello.txt","r")
print(f.read()) # Hello World!
f.close()
# Out:
# Hello World!

# %%
# Read File -> r
f = open("hello.txt","r")
print(f.read()) # Hello World!
1/0
f.close()
# Out:
# Hello World!
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Read File -> r
#       2 f = open("hello.txt","r")
#       3 print(f.read()) # Hello World!
# ----> 4 1/0
#       5 f.close()
#
# ZeroDivisionError: division by zero

# %%
f.closed
# Out:
# False

# %%
def division(a,b):
    div = a/b
    return div

division(5,2)
# Out:
# 2.5

# %%
division(5,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 division(5,0)
#
# Cell In[7], line 2, in division(a, b)
#       1 def division(a,b):
# ----> 2     div = a/b
#       3     return div
#
# ZeroDivisionError: division by zero

# %%
# Error Handling/ Exception handling

# %%
def division(a,b):
    try: 
        div = a/b
        return div
    except ZeroDivisionError:
        print("Cannot be divided by 0")


division(5,2)
# Out:
# 2.5

# %%
division(5,0)
print("Hello world!!")
# Out:
# Cannot be divided by 0
# Hello world!!

# %%
division(5,'a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 division(5,'a')
#
# Cell In[9], line 5, in division(a, b)
#       1 def division(a,b):
#       2     try:
#       3         div = a/b
#       4         return div
# ----> 5     except ZeroDivisionError:
#       6         print("Cannot be divided by 0")
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
def division(a,b):
    try: 
        div = a/b
        return div
    except ZeroDivisionError:
        print("Cannot be divided by 0")
    except TypeError:
        print("Invalid datatype")
# Out:
# Cannot be divided by 0
# Invalid type
# 2.5

# %%
division(5,0)
# Out:
# Cannot be divided by 0

# %%
division(5,2)
# Out:
# 2.5

# %%
division(5,'a')
# Out:
# Invalid type

# %%
def division(a,b):
    try: 
        div = a/b
        return div
    except ZeroDivisionError:
        print("Cannot be divided by 0")
    except TypeError:
        print("Invalid datatype")
    except Exception as e:
        print(e)

# %%
division(5,False)
# Out:
# Cannot be divided by 0

# %%
division(5,0)
# Out:
# Cannot be divided by 0

# %%
division(5,0)
# Out:
# Cannot be divided by 0

# %%
def division(a,b):
    try: 
        div = a/b
        return div
    except Exception as e:
        print(e)

# %%
division(5,2)
# Out:
# 2.5

# %%
division(5,0)
# Out:
# Cannot be divided by 0

# %%
division(5,'a')
# Out:
# unsupported operand type(s) for /: 'int' and 'str'

# %%
division('a','b')
# Out:
# unsupported operand type(s) for /: 'str' and 'str'

# %%
division(0,0)
# Out:
# division by zero

# %%
division(0,4)
# Out:
# 0.0

# %%
def division(a,b):
    try: 
        div = a/b
    except ZeroDivisionError:
        print("Cannot be divided by 0")
    except TypeError:
        print("Invalid datatype")
    except Exception as e:
        print(e)
    else:
        print("I will run if there is not exception raised")
        return div

# %%
division(5,2)
# Out:
# I will run if there is not exception raised
# 2.5

# %%
division(5,0)
# Out:
# Cannot be divided by 0

# %%
division(5,'a')
# Out:
# Invalid datatype

# %%
division('str','str')
# Out:
# Invalid datatype

# %%
def division(a,b):
    try: 
        div = a/b
    except ZeroDivisionError:
        print("Cannot be divided by 0")
    except TypeError:
        print("Invalid datatype")
    except Exception as e:
        print(e)
    else:
        print("I will run if there is not exception raised")
        return div
    finally:
        print("I will run no matter what happens in the code")

# %%
division(5,2)
# Out:
# I will run if there is not exception raised
# I will run no matter what happens in the code
# 2.5

# %%
division(5,'a')
# Out:
# Invalid datatype
# I will run no matter what happens in the code

# %%
# Read File -> r
f = open("hello.txt","r")
print(f.read()) # Hello World!
try: 
    1/0
except Exception as e:
    print(e)
f.close()
# Out:
# Hello World!
# division by zero

# %%
f.closed
# Out:
# True
